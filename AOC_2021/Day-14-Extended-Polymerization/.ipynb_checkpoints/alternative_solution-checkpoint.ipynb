# %%
from collections import Counter

# %%
with open('sample.txt') as reader:
    line, _, *rest = reader.read().split('\n')
    # line = 'NNCB'
    first = line[0]
    # first = N
    start = Counter(map("".join, zip(line, line[1:])))
    # start = Counter({'NN': 1, 'NC': 1, 'CB': 1})
    data = dict(l.split(' -> ') for l in rest)
    # {'CH': 'B',
    #  'HH': 'N',
    #  'CB': 'H',
    #  'NH': 'C',
    #  'HB': 'C',
    #  'HC': 'B',
    #  'HN': 'C',
    #  'NN': 'C',
    #  'BH': 'H',
    #  'NC': 'B',
    #  'NB': 'B',
    #  'BN': 'B',
    #  'BB': 'N',
    #  'BC': 'B',
    #  'CC': 'N',
    #  'CN': 'C'}

# %%
def step(mp):
    n = Counter()
    for k, v in mp.items():
        print(f'n[k[0]+data[k]] = {n[k[0]+data[k]]}')
        n[k[0]+data[k]] = n[k[0]+data[k]] + v
        n[data[k]+k[1]] = n[data[k]+k[1]] + v
    return n


def solve(iters):
    data = start.copy()
    for _ in range(iters):
        data = step(data)

    counts = Counter()
    for k, v in data.items():
        counts[k[1]] += v
    counts[first] += 1
    counts = counts.most_common()

    return counts[0][1] - counts[-1][1]


print("Part 1:", solve(10))
print("Part 2:", solve(40))
# Out:
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1
# n[k[0]+data[k]] = 1
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 4
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 8
# n[k[0]+data[k]] = 2
# n[k[0]+data[k]] = 7
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 9
# n[k[0]+data[k]] = 15
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 18
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 5
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 19
# n[k[0]+data[k]] = 34
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 38
# n[k[0]+data[k]] = 6
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 6
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 8
# n[k[0]+data[k]] = 3
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 41
# n[k[0]+data[k]] = 75
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 83
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 14
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 6
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 3
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 87
# n[k[0]+data[k]] = 163
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 174
# n[k[0]+data[k]] = 19
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 17
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 23
# n[k[0]+data[k]] = 10
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 3
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 183
# n[k[0]+data[k]] = 346
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 371
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 40
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 19
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 9
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 384
# n[k[0]+data[k]] = 735
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 768
# n[k[0]+data[k]] = 60
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 49
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 66
# n[k[0]+data[k]] = 32
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 10
# Part 1: 1588
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1
# n[k[0]+data[k]] = 1
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 4
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 8
# n[k[0]+data[k]] = 2
# n[k[0]+data[k]] = 7
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 9
# n[k[0]+data[k]] = 15
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 18
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 5
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 19
# n[k[0]+data[k]] = 34
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 38
# n[k[0]+data[k]] = 6
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 6
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 8
# n[k[0]+data[k]] = 3
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 41
# n[k[0]+data[k]] = 75
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 83
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 14
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 6
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 3
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 87
# n[k[0]+data[k]] = 163
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 174
# n[k[0]+data[k]] = 19
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 17
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 23
# n[k[0]+data[k]] = 10
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 3
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 183
# n[k[0]+data[k]] = 346
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 371
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 40
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 19
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 9
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 384
# n[k[0]+data[k]] = 735
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 768
# n[k[0]+data[k]] = 60
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 49
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 66
# n[k[0]+data[k]] = 32
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 10
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 796
# n[k[0]+data[k]] = 1531
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1608
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 115
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 60
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 27
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1650
# n[k[0]+data[k]] = 3197
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 3301
# n[k[0]+data[k]] = 189
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 142
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 191
# n[k[0]+data[k]] = 102
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 32
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 3388
# n[k[0]+data[k]] = 6586
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 6823
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 333
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 189
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 81
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 6957
# n[k[0]+data[k]] = 13590
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 13921
# n[k[0]+data[k]] = 593
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 414
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 556
# n[k[0]+data[k]] = 323
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 102
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 14191
# n[k[0]+data[k]] = 27788
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 28516
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 970
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 593
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 244
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 28941
# n[k[0]+data[k]] = 56863
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 57915
# n[k[0]+data[k]] = 1855
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1214
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1628
# n[k[0]+data[k]] = 1018
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 323
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 58752
# n[k[0]+data[k]] = 115648
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 117884
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2842
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1855
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 737
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 119225
# n[k[0]+data[k]] = 235253
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 238583
# n[k[0]+data[k]] = 5788
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 3579
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 4793
# n[k[0]+data[k]] = 3196
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1018
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 241175
# n[k[0]+data[k]] = 476561
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 483430
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 8372
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 5788
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2232
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 487644
# n[k[0]+data[k]] = 965285
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 975781
# n[k[0]+data[k]] = 18022
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 10604
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 14183
# n[k[0]+data[k]] = 10002
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 3196
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 983801
# n[k[0]+data[k]] = 1949579
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1970687
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 24787
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 18022
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 6775
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1983885
# n[k[0]+data[k]] = 3936549
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 3969508
# n[k[0]+data[k]] = 56017
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 31562
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 42166
# n[k[0]+data[k]] = 31220
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 10002
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 3994305
# n[k[0]+data[k]] = 7932592
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 7997475
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 73728
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 56017
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 20606
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 8038697
# n[k[0]+data[k]] = 15980154
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 16083323
# n[k[0]+data[k]] = 173862
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 94334
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 125896
# n[k[0]+data[k]] = 97239
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 31220
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 16159946
# n[k[0]+data[k]] = 32146029
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 32345524
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 220230
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 173862
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 62782
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 32473983
# n[k[0]+data[k]] = 64645644
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 64967736
# n[k[0]+data[k]] = 538965
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 283012
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 377346
# n[k[0]+data[k]] = 302321
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 97239
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 65204380
# n[k[0]+data[k]] = 129869794
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 130483323
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 660358
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 538965
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 191573
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 130882883
# n[k[0]+data[k]] = 260827240
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 261830607
# n[k[0]+data[k]] = 1669063
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 851931
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1134943
# n[k[0]+data[k]] = 938525
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 302321
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 262561145
# n[k[0]+data[k]] = 523453226
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 525340460
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1986874
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1669063
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 585333
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 526581306
# n[k[0]+data[k]] = 1050252702
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1053372658
# n[k[0]+data[k]] = 5164305
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2572207
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 3424138
# n[k[0]+data[k]] = 2909909
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 938525
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1055627054
# n[k[0]+data[k]] = 2106089802
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2111895992
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 5996345
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 5164305
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1790456
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2115744426
# n[k[0]+data[k]] = 4222476112
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 4232162838
# n[k[0]+data[k]] = 15967500
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 7786801
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 10359008
# n[k[0]+data[k]] = 9012739
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 2909909
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 4239117599
# n[k[0]+data[k]] = 8462267697
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 8480133418
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 18145809
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 15967500
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 5482116
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 8492056066
# n[k[0]+data[k]] = 16956221983
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 16986258763
# n[k[0]+data[k]] = 49339764
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 23627925
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 31414726
# n[k[0]+data[k]] = 27890148
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 9012739
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 17007708379
# n[k[0]+data[k]] = 33966076993
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 34021056927
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 55042651
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 49339764
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 16799540
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 34057959814
# n[k[0]+data[k]] = 68029676976
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 68122716335
# n[k[0]+data[k]] = 152381955
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 71842191
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 95470116
# n[k[0]+data[k]] = 86242651
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 27890148
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 68188855639
# n[k[0]+data[k]] = 136225329322
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 136394542495
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 167312307
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 152381955
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 51518073
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 136508675294
# n[k[0]+data[k]] = 272750835833
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 273038768526
# n[k[0]+data[k]] = 470414782
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 218830380
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 290672571
# n[k[0]+data[k]] = 266514754
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 86242651
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 273242668554
# n[k[0]+data[k]] = 546014922325
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 546535761360
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 509502951
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 470414782
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 158084842
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 546888518765
# n[k[0]+data[k]] = 1092953865342
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 1093844270654
# n[k[0]+data[k]] = 1451671811
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 667587793
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 886418173
# n[k[0]+data[k]] = 823172187
# n[k[0]+data[k]] = 0
# n[k[0]+data[k]] = 266514754
# Part 2: 2188189693529
